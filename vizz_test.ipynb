# %% [markdown]
# <a href="https://colab.research.google.com/github/yuki-shi/pokedex-flask/blob/main/vizz_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.read_csv('https://raw.githubusercontent.com/yuki-shi/pokedex-flask/main/pokemon.csv')
df.tail()
# Out:
#      No.       Name   HP  Att  Def  S.Att  S.Def  Spd   Type 1  Type 2  \
# 146  147    Dratini   41   64   45     50     50   50   dragon     NaN
# 147  148  Dragonair   61   84   65     70     70   70   dragon     NaN
# 148  149  Dragonite   91  134   95    100    100   80   dragon  flying
# 149  150     Mewtwo  106  110   90    154     90  130  psychic     NaN
# 150  151        Mew  100  100  100    100    100  100  psychic     NaN
#
#      Height  Weight    Ability 1 Hidden Ability     Ability 2 Legendary
# 146    18.0    33.0    shed-skin   marvel-scale  marvel-scale        No
# 147    40.0   165.0    shed-skin   marvel-scale  marvel-scale        No
# 148    22.0  2100.0  inner-focus     multiscale    multiscale        No
# 149    20.0  1220.0     pressure        unnerve       unnerve       Yes
# 150     4.0    40.0  synchronize            NaN           NaN       Yes

# %%
df.corr()
# Out:
#              No.        HP       Att       Def     S.Att     S.Def       Spd  \
# No.     1.000000  0.204389  0.254606  0.325882  0.255471  0.256101  0.132792
# HP      0.204389  1.000000  0.296823  0.119782  0.236649  0.493723 -0.041245
# Att     0.254606  0.296823  1.000000  0.482674  0.140266  0.370101  0.201238
# Def     0.325882  0.119782  0.482674  1.000000  0.187569  0.141566 -0.052380
# S.Att   0.255471  0.236649  0.140266  0.187569  1.000000  0.528256  0.407782
# S.Def   0.256101  0.493723  0.370101  0.141566  0.528256  1.000000  0.387824
# Spd     0.132792 -0.041245  0.201238 -0.052380  0.407782  0.387824  1.000000
# Height  0.220653  0.243342  0.307233  0.357712  0.156818  0.311699  0.202517
# Weight  0.268325  0.449791  0.459233  0.413290  0.149301  0.375299  0.059920
#
#           Height    Weight
# No.     0.220653  0.268325
# HP      0.243342  0.449791
# Att     0.307233  0.459233
# Def     0.357712  0.413290
# S.Att   0.156818  0.149301
# S.Def   0.311699  0.375299
# ...

# %%
df2 = df
df2.loc[df2['Type 2'].isnull(), 'Type 2'] = df2['Type 1']
df2[df2['Type 2'].isnull()]
df2 = df.groupby(['Type 1', 'Type 2']).nunique()['No.'].reset_index()
df2 = df2.sort_values('No.', ascending=False)

fig = go.Figure(data=go.Heatmap(
                        z=df2['No.'],
                        x=df2['Type 1'],
                        y=df2['Type 2'],
                        hoverongaps=False,
                        colorscale='Viridis'))

fig.update_layout(
#    paper_bgcolor='rgba(0,0,0,0)',
#    plot_bgcolor='rgba(0,0,0,0)',
    height=550,
    width=550
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
filter = 'grass'
color = 'rgba(53, 170, 114, 0.95)'

# %%
df3 = df.loc[(df['Type 1'] == f'{filter}') | (df['Type 2'] == f'{filter}'), :]
df3.loc[df3['Type 2'].isnull(), 'Type 2'] = df3['Type 1']
df3 = df3.groupby(['Type 1', 'Type 2']).nunique()['No.'].reset_index()
df3.loc[df3['Type 1'] == df3['Type 2'], 'type-agg'] = df3['Type 1']
df3.loc[df3['Type 1'] != df3['Type 2'], 'type-agg'] = df3[['Type 1', 'Type 2']].transpose().agg(' + '.join)
df3.sort_values('No.', ascending=False, inplace=True)

fig = go.Figure(data=[go.Bar(x=df3['type-agg'], y=df3['No.'])])
fig.update_layout(width=750, height=550)
fig.update_traces(marker_color=color)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df3
# Out:
#      No.        Name  HP  Att  Def  S.Att  S.Def  Spd Type 1   Type 2  Height  \
# 0      1   Bulbasaur  45   49   49     65     65   45  grass   poison     7.0
# 1      2     Ivysaur  60   62   63     80     80   60  grass   poison    10.0
# 2      3    Venusaur  80   82   83    100    100   80  grass   poison    20.0
# 42    43      Oddish  45   50   55     75     65   30  grass   poison     5.0
# 43    44       Gloom  60   65   70     85     75   40  grass   poison     8.0
# 44    45   Vileplume  75   80   85    110     90   50  grass   poison    12.0
# 45    46       Paras  35   70   55     45     55   25    bug    grass     3.0
# 46    47    Parasect  60   95   80     60     80   30    bug    grass    10.0
# 68    69  Bellsprout  50   75   35     70     30   40  grass   poison     7.0
# 69    70  Weepinbell  65   90   50     85     45   55  grass   poison    10.0
# 70    71  Victreebel  80  105   65    100     70   70  grass   poison    17.0
# ...

# %%
df3 = df.loc[(df['Type 1'] == f'{filter}') | (df['Type 2'] == f'{filter}'), :]
df_cat = df3.select_dtypes(exclude='object')
df_cat = df_cat.drop('No.', axis=1)
df_stats = df_cat[['HP', 'Att', 'Def', 'S.Att', 'S.Def', 'Spd']]

# %%
fig = go.Figure()

for column in df_stats.columns:
  fig.add_trace(go.Box(y=df_stats[column], name=column))

fig.update_layout(height=550,
                  width=550)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df3['Ability 1'].value_counts()
# Out:
# chlorophyll     9
# overgrow        3
# effect-spore    2
# Name: Ability 1, dtype: int64
